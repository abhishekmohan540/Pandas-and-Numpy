# %%
d1 = {"key1": [1,2,3,4,5],
     "key2" : [6,7,8,9,10],
     "key3" : [11,12,13,14,15],
      "key4" : [16,17,18,19,20]
     }

# %%
import pandas as pd

# %%
pd.DataFrame(d1)
# Out:
#    key1  key2  key3  key4
# 0     1     6    11    16
# 1     2     7    12    17
# 2     3     8    13    18
# 3     4     9    14    19
# 4     5    10    15    20

# %%
d1 = {"key1": [1,2,3,4,"abhi"],
     "key2" : [6,7,8,9,10],
     "key3" : [11,12,13,14,15],
      "key4" : [16,17,18,19,20]
     }

# %%
df1 = pd.DataFrame(d1)

# %%
df1
# Out:
#    key1  key2  key3  key4
# 0     1     6    11    16
# 1     2     7    12    17
# 2     3     8    13    18
# 3     4     9    14    19
# 4  abhi    10    15    20

# %%
d2 = {"key1": [1,2,3,4,"abhi"],
     "key2" : [6,7,"mohan",9,10],
     "key3" : [11,12,13,14,15],
      "key4" : [16,17,"ineuron","pwskills",20]
     }

# %%
df2 = pd.DataFrame(d2)

# %%
df2
# Out:
#    key1   key2  key3      key4
# 0     1      6    11        16
# 1     2      7    12        17
# 2     3  mohan    13   ineuron
# 3     4      9    14  pwskills
# 4  abhi     10    15        20

# %%
df = pd.DataFrame(d2, index = ["row1", "row2", "row3", "row4", "row5"])

# %%
df
# Out:
#       key1   key2  key3      key4
# row1     1      6    11        16
# row2     2      7    12        17
# row3     3  mohan    13   ineuron
# row4     4      9    14  pwskills
# row5  abhi     10    15        20

# %%
dfame = pd.DataFrame(d2, columns = ["col-1", "col-2", "col-3", "col-4"])

# %%
dfame
# Out:
# Empty DataFrame
# Columns: [col-1, col-2, col-3, col-4]
# Index: []

# %%
df1
# Out:
#    key1  key2  key3  key4
# 0     1     6    11    16
# 1     2     7    12    17
# 2     3     8    13    18
# 3     4     9    14    19
# 4  abhi    10    15    20

# %%
df2
# Out:
#    key1   key2  key3      key4
# 0     1      6    11        16
# 1     2      7    12        17
# 2     3  mohan    13   ineuron
# 3     4      9    14  pwskills
# 4  abhi     10    15        20

# %%
#Merge can be treated as inner join of sql.

# %%
# merge will give those rows as output which are same in both the table

# %%
pd.merge(df1,df2)
# Out:
#    key1 key2  key3 key4
# 0     1    6    11   16
# 1     2    7    12   17
# 2  abhi   10    15   20

# %%
pd.merge(df1,df2, how = 'inner')
# Out:
#    key1 key2  key3 key4
# 0     1    6    11   16
# 1     2    7    12   17
# 2  abhi   10    15   20

# %%
pd.merge(df1,df2, how = 'outer')
# Out:
# /tmp/ipykernel_1640/3563974710.py:1: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   pd.merge(df1,df2, how = 'outer')
#    key1   key2  key3      key4
# 0     1    6.0    11      16.0
# 1     2    7.0    12      17.0
# 2     3    8.0    13      18.0
# 3     4    9.0    14      19.0
# 4  abhi   10.0    15      20.0
# 5     3  mohan    13   ineuron
# 6     4      9    14  pwskills

# %%
pd.merge(df1,df2, how = 'left')
# Out:
#    key1 key2  key3 key4
# 0     1    6    11   16
# 1     2    7    12   17
# 2     3    8    13   18
# 3     4    9    14   19
# 4  abhi   10    15   20

# %%
pd.merge(df1,df2, how = 'right')
# Out:
# /tmp/ipykernel_1640/2366455152.py:1: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   pd.merge(df1,df2, how = 'right')
#    key1   key2  key3      key4
# 0     1    6.0    11      16.0
# 1     2    7.0    12      17.0
# 2     3  mohan    13   ineuron
# 3     4      9    14  pwskills
# 4  abhi   10.0    15      20.0

# %%
pd.merge(df1,df2, how = 'inner', on = "key1")
# Out:
#    key1  key2_x  key3_x  key4_x key2_y  key3_y    key4_y
# 0     1       6      11      16      6      11        16
# 1     2       7      12      17      7      12        17
# 2     3       8      13      18  mohan      13   ineuron
# 3     4       9      14      19      9      14  pwskills
# 4  abhi      10      15      20     10      15        20

# %%
pd.merge(df1,df2, how = 'inner', on = "key2")
# Out:
#   key1_x key2  key3_x  key4_x key1_y  key3_y    key4_y
# 0      1    6      11      16      1      11        16
# 1      2    7      12      17      2      12        17
# 2      4    9      14      19      4      14  pwskills
# 3   abhi   10      15      20   abhi      15        20

# %%
pd.merge(df1,df2, how = 'inner', on = "key4")
# Out:
#   key1_x  key2_x  key3_x key4 key1_y key2_y  key3_y
# 0      1       6      11   16      1      6      11
# 1      2       7      12   17      2      7      12
# 2   abhi      10      15   20   abhi     10      15

# %%
df1
# Out:
#    key1  key2  key3  key4
# 0     1     6    11    16
# 1     2     7    12    17
# 2     3     8    13    18
# 3     4     9    14    19
# 4  abhi    10    15    20

# %%
df2
# Out:
#    key1   key2  key3      key4
# 0     1      6    11        16
# 1     2      7    12        17
# 2     3  mohan    13   ineuron
# 3     4      9    14  pwskills
# 4  abhi     10    15        20

# %%
pd.merge(df1,df2, how = 'left', on = "key4")
# Out:
#   key1_x  key2_x  key3_x key4 key1_y key2_y  key3_y
# 0      1       6      11   16      1      6    11.0
# 1      2       7      12   17      2      7    12.0
# 2      3       8      13   18    NaN    NaN     NaN
# 3      4       9      14   19    NaN    NaN     NaN
# 4   abhi      10      15   20   abhi     10    15.0

# %%
pd.merge(df1,df2, how = 'left', on = "key2")
# Out:
#   key1_x key2  key3_x  key4_x key1_y  key3_y    key4_y
# 0      1    6      11      16      1    11.0        16
# 1      2    7      12      17      2    12.0        17
# 2      3    8      13      18    NaN     NaN       NaN
# 3      4    9      14      19      4    14.0  pwskills
# 4   abhi   10      15      20   abhi    15.0        20

# %%
pd.merge(df1,df2, how = 'right', on = "key4")
# Out:
# /tmp/ipykernel_1640/498233479.py:1: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   pd.merge(df1,df2, how = 'right', on = "key4")
#   key1_x  key2_x  key3_x      key4 key1_y key2_y  key3_y
# 0      1     6.0    11.0      16.0      1      6      11
# 1      2     7.0    12.0      17.0      2      7      12
# 2    NaN     NaN     NaN   ineuron      3  mohan      13
# 3    NaN     NaN     NaN  pwskills      4      9      14
# 4   abhi    10.0    15.0      20.0   abhi     10      15

# %%
# Left merge means everything from left table and common rows from right table.
# Right merge means everything from right table and common rows from left table.

# %%
# NaN means Not a number.

# %%
df1
# Out:
#    key1  key2  key3  key4
# 0     1     6    11    16
# 1     2     7    12    17
# 2     3     8    13    18
# 3     4     9    14    19
# 4  abhi    10    15    20

# %%
df2
# Out:
#    key1   key2  key3      key4
# 0     1      6    11        16
# 1     2      7    12        17
# 2     3  mohan    13   ineuron
# 3     4      9    14  pwskills
# 4  abhi     10    15        20

# %%
pd.merge(df1,df2, how = 'outer', on = "key4")
# Out:
# /tmp/ipykernel_1640/2378372937.py:1: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   pd.merge(df1,df2, how = 'outer', on = "key4")
#   key1_x  key2_x  key3_x      key4 key1_y key2_y  key3_y
# 0      1     6.0    11.0      16.0      1      6    11.0
# 1      2     7.0    12.0      17.0      2      7    12.0
# 2      3     8.0    13.0      18.0    NaN    NaN     NaN
# 3      4     9.0    14.0      19.0    NaN    NaN     NaN
# 4   abhi    10.0    15.0      20.0   abhi     10    15.0
# 5    NaN     NaN     NaN   ineuron      3  mohan    13.0
# 6    NaN     NaN     NaN  pwskills      4      9    14.0

# %%
pd.merge(df1,df2, how = 'outer')
# Out:
# /tmp/ipykernel_1640/3563974710.py:1: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   pd.merge(df1,df2, how = 'outer')
#    key1   key2  key3      key4
# 0     1    6.0    11      16.0
# 1     2    7.0    12      17.0
# 2     3    8.0    13      18.0
# 3     4    9.0    14      19.0
# 4  abhi   10.0    15      20.0
# 5     3  mohan    13   ineuron
# 6     4      9    14  pwskills

# %%
# Outer :-first table all rows, including Common rows from both the table and then remaining rows of second table.

# %%
pd.merge(df1,df2, how = 'inner', on = ["key1", "key4"])
# Out:
#    key1  key2_x  key3_x key4 key2_y  key3_y
# 0     1       6      11   16      6      11
# 1     2       7      12   17      7      12
# 2  abhi      10      15   20     10      15

# %%
d1
# Out:
# {'key1': [1, 2, 3, 4, 'abhi'],
#  'key2': [6, 7, 8, 9, 10],
#  'key3': [11, 12, 13, 14, 15],
#  'key4': [16, 17, 18, 19, 20]}

# %%
d11 = {"a": [1,2,3,4,"abhi"],
     "b" : [6,7,8,9,10],
     "c" : [11,12,13,14,15],
      "d" : [16,17,18,19,20]
     }

# %%
df11 = pd.DataFrame(d11)

# %%
df11
# Out:
#       a   b   c   d
# 0     1   6  11  16
# 1     2   7  12  17
# 2     3   8  13  18
# 3     4   9  14  19
# 4  abhi  10  15  20

# %%
d12 = {"key1": [1,2,3,4,"abhi"],
     "key2" : [6,7,"mohan",9,10],
     "key3" : [11,12,13,14,15],
      "key4" : [16,17,"ineuron","pwskills",20]
     }

# %%
df12 = pd.DataFrame(d12)

# %%
df12
# Out:
#    key1   key2  key3      key4
# 0     1      6    11        16
# 1     2      7    12        17
# 2     3  mohan    13   ineuron
# 3     4      9    14  pwskills
# 4  abhi     10    15        20

# %%
# NOw since we have changed column names of both the table,then how to do the merge operations

# %%
pd.merge(df11,df12)
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# Cell In [51], line 1
# ----> 1 pd.merge(df11,df12)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/reshape/merge.py:110, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      93 @Substitution("\nleft : DataFrame or named Series")
#      94 @Appender(_merge_doc, indents=0)
#      95 def merge(
#    (...)
#     108     validate: str | None = None,
#     109 ) -> DataFrame:
# --> 110     op = _MergeOperation(
#     111         left,
#     112         right,
#     113         how=how,
#     114         on=on,
#     115         left_on=left_on,
#     116         right_on=right_on,
#     117         left_index=left_index,
#     118         right_index=right_index,
#     119         sort=sort,
#     120         suffixes=suffixes,
# ...

# %%
pd.merge(df11, df12, left_on='a', right_on = 'key1')
# Out:
#       a   b   c   d  key1   key2  key3      key4
# 0     1   6  11  16     1      6    11        16
# 1     2   7  12  17     2      7    12        17
# 2     3   8  13  18     3  mohan    13   ineuron
# 3     4   9  14  19     4      9    14  pwskills
# 4  abhi  10  15  20  abhi     10    15        20

# %%
pd.merge(df11, df12, left_on='d', right_on = 'key4')
# Out:
#       a   b   c   d  key1 key2  key3 key4
# 0     1   6  11  16     1    6    11   16
# 1     2   7  12  17     2    7    12   17
# 2  abhi  10  15  20  abhi   10    15   20

# %%
pd.merge(df11, df12, left_on='d', right_on = 'key1')
# Out:
# Empty DataFrame
# Columns: [a, b, c, d, key1, key2, key3, key4]
# Index: []

# %%
pd.merge(df11, df12, left_on='a', right_on = 'key4')
# Out:
# Empty DataFrame
# Columns: [a, b, c, d, key1, key2, key3, key4]
# Index: []

# %% [markdown]
# ## JOIN operations

# %%
df1
# Out:
#    key1  key2  key3  key4
# 0     1     6    11    16
# 1     2     7    12    17
# 2     3     8    13    18
# 3     4     9    14    19
# 4  abhi    10    15    20

# %%
df2
# Out:
#    key1   key2  key3      key4
# 0     1      6    11        16
# 1     2      7    12        17
# 2     3  mohan    13   ineuron
# 3     4      9    14  pwskills
# 4  abhi     10    15        20

# %%
df1.join(df2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [64], line 1
# ----> 1 df1.join(df2)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/frame.py:9966, in DataFrame.join(self, other, on, how, lsuffix, rsuffix, sort, validate)
#    9803 def join(
#    9804     self,
#    9805     other: DataFrame | Series | list[DataFrame | Series],
#    (...)
#    9811     validate: str | None = None,
#    9812 ) -> DataFrame:
#    9813     """
#    9814     Join columns of another DataFrame.
#    9815
#    (...)
#    9964     5  K1  A5   B1
#    9965     """
# -> 9966     return self._join_compat(
#    9967         other,
#    9968         on=on,
#    9969         how=how,
#    9970         lsuffix=lsuffix,
#    9971         rsuffix=rsuffix,
#    9972         sort=sort,
#    9973         validate=validate,
#    9974     )
#
# ...

# %%
d10 = {"key10": [1,2,3,4,"abhi"],
     "key20" : [6,7,8,9,10],
     "key30" : [11,12,13,14,15],
      "key40" : [16,17,18,19,20]
     }

# %%
d20 = {"key1": [1,2,3,4,"abhi"],
     "key2" : [6,7,"mohan",9,10],
     "key3" : [11,12,13,14,15],
      "key4" : [16,17,"ineuron","pwskills",20]
     }

# %%
df10 = pd.DataFrame(d10)

# %%
df20 = pd.DataFrame(d20)

# %%
df10
# Out:
#   key10  key20  key30  key40
# 0     1      6     11     16
# 1     2      7     12     17
# 2     3      8     13     18
# 3     4      9     14     19
# 4  abhi     10     15     20

# %%
df20
# Out:
#    key1   key2  key3      key4
# 0     1      6    11        16
# 1     2      7    12        17
# 2     3  mohan    13   ineuron
# 3     4      9    14  pwskills
# 4  abhi     10    15        20

# %%
df10.join(df20)
# Out:
#   key10  key20  key30  key40  key1   key2  key3      key4
# 0     1      6     11     16     1      6    11        16
# 1     2      7     12     17     2      7    12        17
# 2     3      8     13     18     3  mohan    13   ineuron
# 3     4      9     14     19     4      9    14  pwskills
# 4  abhi     10     15     20  abhi     10    15        20

# %%
df10.join(df20, how = 'right')
# Out:
#   key10  key20  key30  key40  key1   key2  key3      key4
# 0     1      6     11     16     1      6    11        16
# 1     2      7     12     17     2      7    12        17
# 2     3      8     13     18     3  mohan    13   ineuron
# 3     4      9     14     19     4      9    14  pwskills
# 4  abhi     10     15     20  abhi     10    15        20

# %%
df10.join(df20, how = 'outer')
# Out:
#   key10  key20  key30  key40  key1   key2  key3      key4
# 0     1      6     11     16     1      6    11        16
# 1     2      7     12     17     2      7    12        17
# 2     3      8     13     18     3  mohan    13   ineuron
# 3     4      9     14     19     4      9    14  pwskills
# 4  abhi     10     15     20  abhi     10    15        20

# %%
# We can see that output in all case is same.

# %%
# NOw we will do some changes in index

# %%
df10 = pd.DataFrame(d10, index=[1,2,3,4,5])

# %%
df20 = pd.DataFrame(d20, index=[1,2,3,4,"mohan"])

# %%
df10
# Out:
#   key10  key20  key30  key40
# 1     1      6     11     16
# 2     2      7     12     17
# 3     3      8     13     18
# 4     4      9     14     19
# 5  abhi     10     15     20

# %%
df20
# Out:
#        key1   key2  key3      key4
# 1         1      6    11        16
# 2         2      7    12        17
# 3         3  mohan    13   ineuron
# 4         4      9    14  pwskills
# mohan  abhi     10    15        20

# %%
df10.join(df20)
# Out:
#   key10  key20  key30  key40 key1   key2  key3      key4
# 1     1      6     11     16    1      6  11.0        16
# 2     2      7     12     17    2      7  12.0        17
# 3     3      8     13     18    3  mohan  13.0   ineuron
# 4     4      9     14     19    4      9  14.0  pwskills
# 5  abhi     10     15     20  NaN    NaN   NaN       NaN

# %%
# By default, it is left join.
# Everything from left table and only common from right table.
# Common is decided based on indexes.
# Since the last index didnot matched in right table so nan values are present there.

# %%
df10.join(df20, how = 'right')
# Out:
#       key10  key20  key30  key40  key1   key2  key3      key4
# 1         1    6.0   11.0   16.0     1      6    11        16
# 2         2    7.0   12.0   17.0     2      7    12        17
# 3         3    8.0   13.0   18.0     3  mohan    13   ineuron
# 4         4    9.0   14.0   19.0     4      9    14  pwskills
# mohan   NaN    NaN    NaN    NaN  abhi     10    15        20

# %%
#Everything from right table and common from left table.
# Since the last index didnot matched with left table so nan values are present there.

# %%
df10.join(df20, how = 'outer')
# Out:
#       key10  key20  key30  key40  key1   key2  key3      key4
# 1         1    6.0   11.0   16.0     1      6  11.0        16
# 2         2    7.0   12.0   17.0     2      7  12.0        17
# 3         3    8.0   13.0   18.0     3  mohan  13.0   ineuron
# 4         4    9.0   14.0   19.0     4      9  14.0  pwskills
# 5      abhi   10.0   15.0   20.0   NaN    NaN   NaN       NaN
# mohan   NaN    NaN    NaN    NaN  abhi     10  15.0        20

# %%
df10.join(df20, how = 'inner')
# Out:
#   key10  key20  key30  key40 key1   key2  key3      key4
# 1     1      6     11     16    1      6    11        16
# 2     2      7     12     17    2      7    12        17
# 3     3      8     13     18    3  mohan    13   ineuron
# 4     4      9     14     19    4      9    14  pwskills

# %%
df10
# Out:
#   key10  key20  key30  key40
# 1     1      6     11     16
# 2     2      7     12     17
# 3     3      8     13     18
# 4     4      9     14     19
# 5  abhi     10     15     20

# %%
df20
# Out:
#        key1   key2  key3      key4
# 1         1      6    11        16
# 2         2      7    12        17
# 3         3  mohan    13   ineuron
# 4         4      9    14  pwskills
# mohan  abhi     10    15        20

# %%
# Join works on indexes and merge works on columns.

# %%
pd.concat([df10,df20], axis =0)
# Out:
#       key10  key20  key30  key40  key1   key2  key3      key4
# 1         1    6.0   11.0   16.0   NaN    NaN   NaN       NaN
# 2         2    7.0   12.0   17.0   NaN    NaN   NaN       NaN
# 3         3    8.0   13.0   18.0   NaN    NaN   NaN       NaN
# 4         4    9.0   14.0   19.0   NaN    NaN   NaN       NaN
# 5      abhi   10.0   15.0   20.0   NaN    NaN   NaN       NaN
# 1       NaN    NaN    NaN    NaN     1      6  11.0        16
# 2       NaN    NaN    NaN    NaN     2      7  12.0        17
# 3       NaN    NaN    NaN    NaN     3  mohan  13.0   ineuron
# 4       NaN    NaN    NaN    NaN     4      9  14.0  pwskills
# mohan   NaN    NaN    NaN    NaN  abhi     10  15.0        20

# %%
pd.concat([df10,df20], axis =1)
# Out:
#       key10  key20  key30  key40  key1   key2  key3      key4
# 1         1    6.0   11.0   16.0     1      6  11.0        16
# 2         2    7.0   12.0   17.0     2      7  12.0        17
# 3         3    8.0   13.0   18.0     3  mohan  13.0   ineuron
# 4         4    9.0   14.0   19.0     4      9  14.0  pwskills
# 5      abhi   10.0   15.0   20.0   NaN    NaN   NaN       NaN
# mohan   NaN    NaN    NaN    NaN  abhi     10  15.0        20

# %%
pd.concat([df1,df2], axis =0)
# Out:
#    key1   key2  key3      key4
# 0     1      6    11        16
# 1     2      7    12        17
# 2     3      8    13        18
# 3     4      9    14        19
# 4  abhi     10    15        20
# 0     1      6    11        16
# 1     2      7    12        17
# 2     3  mohan    13   ineuron
# 3     4      9    14  pwskills
# 4  abhi     10    15        20

# %%
pd.concat([df1,df2], axis =1)
# Out:
#    key1 key2  key3 key4  key1   key2  key3      key4
# 0     1    6    11   16     1      6    11        16
# 1     2    7    12   17     2      7    12        17
# 2     3    8    13   18     3  mohan    13   ineuron
# 3     4    9    14   19     4      9    14  pwskills
# 4  abhi   10    15   20  abhi     10    15        20
