# %%
import pandas as pd

# %%
abhi = pd.read_csv("SampleSpreadsheet1.csv", header = None)

# %%
abhi
# Out:
#         0                                                  1  \
# 0       1   Eldon Base for stackable storage shelf, platinum
# 1       2  1.7 Cubic Foot Compact "Cube" Office Refrigera...
# 2       3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl
# 3       4                                               R380
# 4       5                           Holmes HEPA Air Purifier
# ..    ...                                                ...
# 995   996                                         Xerox 1905
# 996   997              Dana Halogen Swing-Arm Architect Lamp
# 997   998                               Maxell DVD-RAM Discs
# 998   999  DAX Contemporary Wood Frame with Silver Metal ...
# 999  1000  Computer Printout Paper with Letter-Trim Perfo...
#
#                       2      3        4       5      6                 7  \
# 0    Muhammed MacIntyre      3  -213.25   38.94  35.00           Nunavut
# 1          Barry French    293   457.81  208.16  68.02           Nunavut
# ...

# %%
type(abhi)
# Out:
# pandas.core.frame.DataFrame

# %%
abhi.head()
# Out:
#    0                                                  1                   2  \
# 0  1   Eldon Base for stackable storage shelf, platinum  Muhammed MacIntyre
# 1  2  1.7 Cubic Foot Compact "Cube" Office Refrigera...        Barry French
# 2  3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl        Barry French
# 3  4                                               R380       Clay Rozendal
# 4  5                           Holmes HEPA Air Purifier      Carlos Soltero
#
#      3        4       5      6        7                               8     9
# 0    3  -213.25   38.94  35.00  Nunavut          Storage & Organization  0.80
# 1  293   457.81  208.16  68.02  Nunavut                      Appliances  0.58
# 2  293    46.71    8.69   2.99  Nunavut  Binders and Binder Accessories  0.39
# 3  483  1198.97  195.99   3.99  Nunavut    Telephones and Communication  0.58
# 4  515    30.94   21.78   5.94  Nunavut                      Appliances  0.50

# %%
abhi.tail()
# Out:
#         0                                                  1  \
# 995   996                                         Xerox 1905
# 996   997              Dana Halogen Swing-Arm Architect Lamp
# 997   998                               Maxell DVD-RAM Discs
# 998   999  DAX Contemporary Wood Frame with Silver Metal ...
# 999  1000  Computer Printout Paper with Letter-Trim Perfo...
#
#                      2      3       4      5      6                 7  \
# 995      Dennis Bolton  48165 -147.27   6.48   9.54  British Columbia
# 996  Anthony O'Donnell  48197  154.74  40.97  14.45  British Columbia
# 997     Barbara Fisher  48484   67.96  16.48   1.99  British Columbia
# 998     Barbara Fisher  48484  133.83  20.24   6.67  British Columbia
# 999     Barbara Fisher  48484  153.80  18.97   9.03  British Columbia
#
#                         8     9
# 995                 Paper  0.37
# 996    Office Furnishings  0.57
# 997  Computer Peripherals  0.42
# 998    Office Furnishings  0.49
# ...

# %%
abhi = pd.read_csv("SampleSpreadsheet1.csv", header = None, names= ['col1', 'col2','col3','col4', 'col5', 'col6','col7', 'col8','col9','col10'])

# %%
abhi
# Out:
#      col1                                               col2  \
# 0       1   Eldon Base for stackable storage shelf, platinum
# 1       2  1.7 Cubic Foot Compact "Cube" Office Refrigera...
# 2       3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl
# 3       4                                               R380
# 4       5                           Holmes HEPA Air Purifier
# ..    ...                                                ...
# 995   996                                         Xerox 1905
# 996   997              Dana Halogen Swing-Arm Architect Lamp
# 997   998                               Maxell DVD-RAM Discs
# 998   999  DAX Contemporary Wood Frame with Silver Metal ...
# 999  1000  Computer Printout Paper with Letter-Trim Perfo...
#
#                    col3   col4     col5    col6   col7              col8  \
# 0    Muhammed MacIntyre      3  -213.25   38.94  35.00           Nunavut
# 1          Barry French    293   457.81  208.16  68.02           Nunavut
# ...

# %%
abhi[['col2']]
# Out:
#                                                   col2
# 0     Eldon Base for stackable storage shelf, platinum
# 1    1.7 Cubic Foot Compact "Cube" Office Refrigera...
# 2     Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl
# 3                                                 R380
# 4                             Holmes HEPA Air Purifier
# ..                                                 ...
# 995                                         Xerox 1905
# 996              Dana Halogen Swing-Arm Architect Lamp
# 997                               Maxell DVD-RAM Discs
# 998  DAX Contemporary Wood Frame with Silver Metal ...
# 999  Computer Printout Paper with Letter-Trim Perfo...
#
# [1000 rows x 1 columns]

# %%
abhi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   col1    1000 non-null   int64
#  1   col2    1000 non-null   object
#  2   col3    1000 non-null   object
#  3   col4    1000 non-null   int64
#  4   col5    1000 non-null   float64
#  5   col6    1000 non-null   float64
#  6   col7    1000 non-null   float64
#  7   col8    1000 non-null   object
#  8   col9    1000 non-null   object
#  9   col10   990 non-null    float64
# dtypes: float64(4), int64(2), object(4)
# memory usage: 78.2+ KB

# %%
abhi.columns
# Out:
# Index(['col1', 'col2', 'col3', 'col4', 'col5', 'col6', 'col7', 'col8', 'col9',
#        'col10'],
#       dtype='object')

# %%
abhi.dtypes
# Out:
# col1       int64
# col2      object
# col3      object
# col4       int64
# col5     float64
# col6     float64
# col7     float64
# col8      object
# col9      object
# col10    float64
# dtype: object

# %%
abhi.describe()
# Out:
#               col1          col4          col5         col6         col7  \
# count  1000.000000   1000.000000   1000.000000  1000.000000  1000.000000
# mean    500.500000  29164.920000    166.124670    86.691280    13.476130
# std     288.819436  17171.970504   1033.422308   206.189401    17.933205
# min       1.000000      3.000000 -11053.600000     1.260000     0.490000
# 25%     250.750000  14347.750000    -86.827500     6.825000     3.300000
# 50%     500.500000  28802.000000      1.190000    22.980000     6.265000
# 75%     750.250000  43371.000000    161.217500    99.990000    14.490000
# max    1000.000000  59750.000000  10951.310000  3499.990000   147.120000
#
#             col10
# count  990.000000
# mean     0.516333
# std      0.136680
# min      0.350000
# 25%      0.380000
# 50%      0.540000
# 75%      0.590000
# max      0.850000

# %%
abhi.head()
# Out:
#    col1                                               col2  \
# 0     1   Eldon Base for stackable storage shelf, platinum
# 1     2  1.7 Cubic Foot Compact "Cube" Office Refrigera...
# 2     3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl
# 3     4                                               R380
# 4     5                           Holmes HEPA Air Purifier
#
#                  col3  col4     col5    col6   col7     col8  \
# 0  Muhammed MacIntyre     3  -213.25   38.94  35.00  Nunavut
# 1        Barry French   293   457.81  208.16  68.02  Nunavut
# 2        Barry French   293    46.71    8.69   2.99  Nunavut
# 3       Clay Rozendal   483  1198.97  195.99   3.99  Nunavut
# 4      Carlos Soltero   515    30.94   21.78   5.94  Nunavut
#
#                              col9  col10
# 0          Storage & Organization   0.80
# 1                      Appliances   0.58
# 2  Binders and Binder Accessories   0.39
# 3    Telephones and Communication   0.58
# ...

# %%
abhi.dtypes == object
# Out:
# col1     False
# col2      True
# col3      True
# col4     False
# col5     False
# col6     False
# col7     False
# col8      True
# col9      True
# col10    False
# dtype: bool

# %%
type(abhi.dtypes)
# Out:
# pandas.core.series.Series

# %%
# Series is like a list. Here, col1,col2,etc are indexes and int, float, object are values,

# %%
abhi.dtypes[abhi.dtypes == object]
# Out:
# col2    object
# col3    object
# col8    object
# col9    object
# dtype: object

# %%
abhi.dtypes[abhi.dtypes == object].index
# Out:
# Index(['col2', 'col3', 'col8', 'col9'], dtype='object')

# %%
abhi[abhi.dtypes[abhi.dtypes == object].index]
# Out:
#                                                   col2                col3  \
# 0     Eldon Base for stackable storage shelf, platinum  Muhammed MacIntyre
# 1    1.7 Cubic Foot Compact "Cube" Office Refrigera...        Barry French
# 2     Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl        Barry French
# 3                                                 R380       Clay Rozendal
# 4                             Holmes HEPA Air Purifier      Carlos Soltero
# ..                                                 ...                 ...
# 995                                         Xerox 1905       Dennis Bolton
# 996              Dana Halogen Swing-Arm Architect Lamp   Anthony O'Donnell
# 997                               Maxell DVD-RAM Discs      Barbara Fisher
# 998  DAX Contemporary Wood Frame with Silver Metal ...      Barbara Fisher
# 999  Computer Printout Paper with Letter-Trim Perfo...      Barbara Fisher
#
#                  col8                            col9
# ...

# %%
abhi[abhi.dtypes[abhi.dtypes == object].index].describe()
# Out:
#                                                  col2            col3  \
# count                                            1000            1000
# unique                                            664             117
# top     Global Leather and Oak Executive Chair, Black  Carlos Soltero
# freq                                                6              33
#
#                          col8   col9
# count                    1000   1000
# unique                      5     17
# top     Northwest Territories  Paper
# freq                      394    129

# %%
# FIlter inly float data type columns

# %%
abhi.dtypes
# Out:
# col1       int64
# col2      object
# col3      object
# col4       int64
# col5     float64
# col6     float64
# col7     float64
# col8      object
# col9      object
# col10    float64
# dtype: object

# %%
abhi.dtypes[abhi.dtypes==float]
# Out:
# col5     float64
# col6     float64
# col7     float64
# col10    float64
# dtype: object

# %%
abhi.dtypes[abhi.dtypes==float].index
# Out:
# Index(['col5', 'col6', 'col7', 'col10'], dtype='object')

# %%
abhi[abhi.dtypes[abhi.dtypes==float].index]
# Out:
#         col5    col6   col7  col10
# 0    -213.25   38.94  35.00   0.80
# 1     457.81  208.16  68.02   0.58
# 2      46.71    8.69   2.99   0.39
# 3    1198.97  195.99   3.99   0.58
# 4      30.94   21.78   5.94   0.50
# ..       ...     ...    ...    ...
# 995  -147.27    6.48   9.54   0.37
# 996   154.74   40.97  14.45   0.57
# 997    67.96   16.48   1.99   0.42
# 998   133.83   20.24   6.67   0.49
# 999   153.80   18.97   9.03   0.37
#
# [1000 rows x 4 columns]

# %%
abhi[abhi.dtypes[abhi.dtypes==float].index].describe()
# Out:
#                col5         col6         col7       col10
# count   1000.000000  1000.000000  1000.000000  990.000000
# mean     166.124670    86.691280    13.476130    0.516333
# std     1033.422308   206.189401    17.933205    0.136680
# min   -11053.600000     1.260000     0.490000    0.350000
# 25%      -86.827500     6.825000     3.300000    0.380000
# 50%        1.190000    22.980000     6.265000    0.540000
# 75%      161.217500    99.990000    14.490000    0.590000
# max    10951.310000  3499.990000   147.120000    0.850000

# %%
abhi.head()
# Out:
#    col1                                               col2  \
# 0     1   Eldon Base for stackable storage shelf, platinum
# 1     2  1.7 Cubic Foot Compact "Cube" Office Refrigera...
# 2     3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl
# 3     4                                               R380
# 4     5                           Holmes HEPA Air Purifier
#
#                  col3  col4     col5    col6   col7     col8  \
# 0  Muhammed MacIntyre     3  -213.25   38.94  35.00  Nunavut
# 1        Barry French   293   457.81  208.16  68.02  Nunavut
# 2        Barry French   293    46.71    8.69   2.99  Nunavut
# 3       Clay Rozendal   483  1198.97  195.99   3.99  Nunavut
# 4      Carlos Soltero   515    30.94   21.78   5.94  Nunavut
#
#                              col9  col10
# 0          Storage & Organization   0.80
# 1                      Appliances   0.58
# 2  Binders and Binder Accessories   0.39
# 3    Telephones and Communication   0.58
# ...

# %%
abhi['col8'].count()
# Out:
# 1000

# %%
abhi['col9'] == 'Appliances'
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4       True
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Name: col9, Length: 1000, dtype: bool

# %%
abhi[abhi['col9'] == 'Appliances']
# Out:
#      col1                                               col2  \
# 1       2  1.7 Cubic Foot Compact "Cube" Office Refrigera...
# 4       5                           Holmes HEPA Air Purifier
# 12     13                           Holmes HEPA Air Purifier
# 44     45                 Hoover Portapower™ Portable Vacuum
# 56     57   APC 7 Outlet Network SurgeArrest Surge Protector
# 73     74                              3M Office Air Cleaner
# 83     84  Acco Smartsocket™ Table Surge Protector, 6 Col...
# 123   124                       Holmes 99% HEPA Air Purifier
# 133   134  Kensington 7 Outlet MasterPiece Power Center w...
# 176   177                             Staples 6 Outlet Surge
# 249   250               Belkin 6 Outlet Metallic Surge Strip
# 257   258   Bionaire Personal Warm Mist Humidifier/Vaporizer
# 286   287                             Staples 6 Outlet Surge
# 289   290  Honeywell Enviracaire Portable HEPA Air Cleane...
# ...

# %%
abhi['col8'] == 'British Columbia'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995     True
# 996     True
# 997     True
# 998     True
# 999     True
# Name: col8, Length: 1000, dtype: bool

# %%
abhi[abhi['col8'] == 'British Columbia']
# Out:
#      col1                                               col2  \
# 735   736                GE 4 Foot Flourescent Tube, 40 Watt
# 736   737  Bush Westfield Collection Bookcases, Fully Ass...
# 737   738                         Nu-Dell Leatherette Frames
# 738   739  Micro Innovations Micro Digital Wireless Keybo...
# 739   740  Snap-A-Way® Black Print Carbonless Ruled Speed...
# ..    ...                                                ...
# 995   996                                         Xerox 1905
# 996   997              Dana Halogen Swing-Arm Architect Lamp
# 997   998                               Maxell DVD-RAM Discs
# 998   999  DAX Contemporary Wood Frame with Silver Metal ...
# 999  1000  Computer Printout Paper with Letter-Trim Perfo...
#
#                   col3   col4    col5    col6   col7              col8  \
# 735        Jack Lebron  59074   70.80   14.98   8.99  British Columbia
# 736        Jack Lebron  59233 -160.46  100.98  35.84  British Columbia
# ...

# %%
abhi['col5'].sum()
# Out:
# 166124.66999999998

# %%
abhi['col5'].count()
# Out:
# 1000

# %%
abhi.count()
# Out:
# col1     1000
# col2     1000
# col3     1000
# col4     1000
# col5     1000
# col6     1000
# col7     1000
# col8     1000
# col9     1000
# col10     990
# dtype: int64

# %%
abhi.head()
# Out:
#    col1                                               col2  \
# 0     1   Eldon Base for stackable storage shelf, platinum
# 1     2  1.7 Cubic Foot Compact "Cube" Office Refrigera...
# 2     3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl
# 3     4                                               R380
# 4     5                           Holmes HEPA Air Purifier
#
#                  col3  col4     col5    col6   col7     col8  \
# 0  Muhammed MacIntyre     3  -213.25   38.94  35.00  Nunavut
# 1        Barry French   293   457.81  208.16  68.02  Nunavut
# 2        Barry French   293    46.71    8.69   2.99  Nunavut
# 3       Clay Rozendal   483  1198.97  195.99   3.99  Nunavut
# 4      Carlos Soltero   515    30.94   21.78   5.94  Nunavut
#
#                              col9  col10
# 0          Storage & Organization   0.80
# 1                      Appliances   0.58
# 2  Binders and Binder Accessories   0.39
# 3    Telephones and Communication   0.58
# ...

# %%
(abhi['col3'] == 'Barry French') & (abhi['col8'] == 'Nunavut')
# Out:
# 0      False
# 1       True
# 2       True
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Length: 1000, dtype: bool

# %%
abhi[(abhi['col3'] == 'Barry French') & (abhi['col8'] == 'Nunavut')]
# Out:
#    col1                                               col2          col3  \
# 1     2  1.7 Cubic Foot Compact "Cube" Office Refrigera...  Barry French
# 2     3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl  Barry French
#
#    col4    col5    col6   col7     col8                            col9  col10
# 1   293  457.81  208.16  68.02  Nunavut                      Appliances   0.58
# 2   293   46.71    8.69   2.99  Nunavut  Binders and Binder Accessories   0.39

# %%
abhi.head(2)
# Out:
#    col1                                               col2  \
# 0     1   Eldon Base for stackable storage shelf, platinum
# 1     2  1.7 Cubic Foot Compact "Cube" Office Refrigera...
#
#                  col3  col4    col5    col6   col7     col8  \
# 0  Muhammed MacIntyre     3 -213.25   38.94  35.00  Nunavut
# 1        Barry French   293  457.81  208.16  68.02  Nunavut
#
#                      col9  col10
# 0  Storage & Organization   0.80
# 1              Appliances   0.58

# %%
abhi['col5'].max()
# Out:
# 10951.31

# %%
abhi['col5'].min()
# Out:
# -11053.6

# %%
abhi['col6'].max()
# Out:
# 3499.99

# %%
abhi['col6'].min()
# Out:
# 1.26

# %%
abhi['col3'][abhi['col5']== abhi['col5'].max()]
# Out:
# 175    Grant Carroll
# Name: col3, dtype: object

# %%
abhi[abhi['col5']== abhi['col5'].max()]
# Out:
#      col1                                               col2           col3  \
# 175   176  Fellowes PB500 Electric Punch Plastic Comb Bin...  Grant Carroll
#
#       col4      col5     col6   col7                   col8  \
# 175  19010  10951.31  1270.99  19.99  Northwest Territories
#
#                                col9  col10
# 175  Binders and Binder Accessories   0.35

# %%
abhi[abhi['col5']== abhi['col5'].max()].col3
# Out:
# 175    Grant Carroll
# Name: col3, dtype: object

# %%
abhi[abhi['col5']== abhi['col5'].max()][['col3']]
# Out:
#               col3
# 175  Grant Carroll

# %%
abhi.head()
# Out:
#    col1                                               col2  \
# 0     1   Eldon Base for stackable storage shelf, platinum
# 1     2  1.7 Cubic Foot Compact "Cube" Office Refrigera...
# 2     3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl
# 3     4                                               R380
# 4     5                           Holmes HEPA Air Purifier
#
#                  col3  col4     col5    col6   col7     col8  \
# 0  Muhammed MacIntyre     3  -213.25   38.94  35.00  Nunavut
# 1        Barry French   293   457.81  208.16  68.02  Nunavut
# 2        Barry French   293    46.71    8.69   2.99  Nunavut
# 3       Clay Rozendal   483  1198.97  195.99   3.99  Nunavut
# 4      Carlos Soltero   515    30.94   21.78   5.94  Nunavut
#
#                              col9  col10
# 0          Storage & Organization   0.80
# 1                      Appliances   0.58
# 2  Binders and Binder Accessories   0.39
# 3    Telephones and Communication   0.58
# ...

# %%
abhi['New_Column'] = abhi['col6'] + abhi['col7']

# %%
abhi.head()
# Out:
#    col1                                               col2  \
# 0     1   Eldon Base for stackable storage shelf, platinum
# 1     2  1.7 Cubic Foot Compact "Cube" Office Refrigera...
# 2     3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl
# 3     4                                               R380
# 4     5                           Holmes HEPA Air Purifier
#
#                  col3  col4     col5    col6   col7     col8  \
# 0  Muhammed MacIntyre     3  -213.25   38.94  35.00  Nunavut
# 1        Barry French   293   457.81  208.16  68.02  Nunavut
# 2        Barry French   293    46.71    8.69   2.99  Nunavut
# 3       Clay Rozendal   483  1198.97  195.99   3.99  Nunavut
# 4      Carlos Soltero   515    30.94   21.78   5.94  Nunavut
#
#                              col9  col10  New_Column
# 0          Storage & Organization   0.80       73.94
# 1                      Appliances   0.58      276.18
# 2  Binders and Binder Accessories   0.39       11.68
# ...

# %%
abhi["new"] = abhi['col2']

# %%
abhi.head()
# Out:
#    col1                                               col2  \
# 0     1   Eldon Base for stackable storage shelf, platinum
# 1     2  1.7 Cubic Foot Compact "Cube" Office Refrigera...
# 2     3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl
# 3     4                                               R380
# 4     5                           Holmes HEPA Air Purifier
#
#                  col3  col4     col5    col6   col7     col8  \
# 0  Muhammed MacIntyre     3  -213.25   38.94  35.00  Nunavut
# 1        Barry French   293   457.81  208.16  68.02  Nunavut
# 2        Barry French   293    46.71    8.69   2.99  Nunavut
# 3       Clay Rozendal   483  1198.97  195.99   3.99  Nunavut
# 4      Carlos Soltero   515    30.94   21.78   5.94  Nunavut
#
#                              col9  col10  New_Column  \
# 0          Storage & Organization   0.80       73.94
# 1                      Appliances   0.58      276.18
# 2  Binders and Binder Accessories   0.39       11.68
# ...

# %%
abhi.drop('new' , axis=1)
# Out:
#      col1                                               col2  \
# 0       1   Eldon Base for stackable storage shelf, platinum
# 1       2  1.7 Cubic Foot Compact "Cube" Office Refrigera...
# 2       3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl
# 3       4                                               R380
# 4       5                           Holmes HEPA Air Purifier
# ..    ...                                                ...
# 995   996                                         Xerox 1905
# 996   997              Dana Halogen Swing-Arm Architect Lamp
# 997   998                               Maxell DVD-RAM Discs
# 998   999  DAX Contemporary Wood Frame with Silver Metal ...
# 999  1000  Computer Printout Paper with Letter-Trim Perfo...
#
#                    col3   col4     col5    col6   col7              col8  \
# 0    Muhammed MacIntyre      3  -213.25   38.94  35.00           Nunavut
# 1          Barry French    293   457.81  208.16  68.02           Nunavut
# ...

# %%
abhi.drop('New_Column', axis=1)
# Out:
#      col1                                               col2  \
# 0       1   Eldon Base for stackable storage shelf, platinum
# 1       2  1.7 Cubic Foot Compact "Cube" Office Refrigera...
# 2       3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl
# 3       4                                               R380
# 4       5                           Holmes HEPA Air Purifier
# ..    ...                                                ...
# 995   996                                         Xerox 1905
# 996   997              Dana Halogen Swing-Arm Architect Lamp
# 997   998                               Maxell DVD-RAM Discs
# 998   999  DAX Contemporary Wood Frame with Silver Metal ...
# 999  1000  Computer Printout Paper with Letter-Trim Perfo...
#
#                    col3   col4     col5    col6   col7              col8  \
# 0    Muhammed MacIntyre      3  -213.25   38.94  35.00           Nunavut
# 1          Barry French    293   457.81  208.16  68.02           Nunavut
# ...

# %%
abhi
# Out:
#      col1                                               col2  \
# 0       1   Eldon Base for stackable storage shelf, platinum
# 1       2  1.7 Cubic Foot Compact "Cube" Office Refrigera...
# 2       3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl
# 3       4                                               R380
# 4       5                           Holmes HEPA Air Purifier
# ..    ...                                                ...
# 995   996                                         Xerox 1905
# 996   997              Dana Halogen Swing-Arm Architect Lamp
# 997   998                               Maxell DVD-RAM Discs
# 998   999  DAX Contemporary Wood Frame with Silver Metal ...
# 999  1000  Computer Printout Paper with Letter-Trim Perfo...
#
#                    col3   col4     col5    col6   col7              col8  \
# 0    Muhammed MacIntyre      3  -213.25   38.94  35.00           Nunavut
# 1          Barry French    293   457.81  208.16  68.02           Nunavut
# ...

# %%
abhi.drop('new' , axis=1, inplace = True)

# %%
abhi
# Out:
#      col1                                               col2  \
# 0       1   Eldon Base for stackable storage shelf, platinum
# 1       2  1.7 Cubic Foot Compact "Cube" Office Refrigera...
# 2       3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl
# 3       4                                               R380
# 4       5                           Holmes HEPA Air Purifier
# ..    ...                                                ...
# 995   996                                         Xerox 1905
# 996   997              Dana Halogen Swing-Arm Architect Lamp
# 997   998                               Maxell DVD-RAM Discs
# 998   999  DAX Contemporary Wood Frame with Silver Metal ...
# 999  1000  Computer Printout Paper with Letter-Trim Perfo...
#
#                    col3   col4     col5    col6   col7              col8  \
# 0    Muhammed MacIntyre      3  -213.25   38.94  35.00           Nunavut
# 1          Barry French    293   457.81  208.16  68.02           Nunavut
# ...

# %%
abhi.drop('New_Column', axis=1, inplace=True)

# %%
abhi
# Out:
#      col1                                               col2  \
# 0       1   Eldon Base for stackable storage shelf, platinum
# 1       2  1.7 Cubic Foot Compact "Cube" Office Refrigera...
# 2       3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl
# 3       4                                               R380
# 4       5                           Holmes HEPA Air Purifier
# ..    ...                                                ...
# 995   996                                         Xerox 1905
# 996   997              Dana Halogen Swing-Arm Architect Lamp
# 997   998                               Maxell DVD-RAM Discs
# 998   999  DAX Contemporary Wood Frame with Silver Metal ...
# 999  1000  Computer Printout Paper with Letter-Trim Perfo...
#
#                    col3   col4     col5    col6   col7              col8  \
# 0    Muhammed MacIntyre      3  -213.25   38.94  35.00           Nunavut
# 1          Barry French    293   457.81  208.16  68.02           Nunavut
# ...

# %%
abhi.drop(0)
# Out:
#      col1                                               col2  \
# 1       2  1.7 Cubic Foot Compact "Cube" Office Refrigera...
# 2       3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl
# 3       4                                               R380
# 4       5                           Holmes HEPA Air Purifier
# 5       6  G.E. Longer-Life Indoor Recessed Floodlight Bulbs
# ..    ...                                                ...
# 995   996                                         Xerox 1905
# 996   997              Dana Halogen Swing-Arm Architect Lamp
# 997   998                               Maxell DVD-RAM Discs
# 998   999  DAX Contemporary Wood Frame with Silver Metal ...
# 999  1000  Computer Printout Paper with Letter-Trim Perfo...
#
#                   col3   col4     col5    col6   col7              col8  \
# 1         Barry French    293   457.81  208.16  68.02           Nunavut
# 2         Barry French    293    46.71    8.69   2.99           Nunavut
# ...

# %%
abhi
# Out:
#      col1                                               col2  \
# 0       1   Eldon Base for stackable storage shelf, platinum
# 1       2  1.7 Cubic Foot Compact "Cube" Office Refrigera...
# 2       3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl
# 3       4                                               R380
# 4       5                           Holmes HEPA Air Purifier
# ..    ...                                                ...
# 995   996                                         Xerox 1905
# 996   997              Dana Halogen Swing-Arm Architect Lamp
# 997   998                               Maxell DVD-RAM Discs
# 998   999  DAX Contemporary Wood Frame with Silver Metal ...
# 999  1000  Computer Printout Paper with Letter-Trim Perfo...
#
#                    col3   col4     col5    col6   col7              col8  \
# 0    Muhammed MacIntyre      3  -213.25   38.94  35.00           Nunavut
# 1          Barry French    293   457.81  208.16  68.02           Nunavut
# ...

# %%
abhi.iloc[0]
# Out:
# col1                                                    1
# col2     Eldon Base for stackable storage shelf, platinum
# col3                                   Muhammed MacIntyre
# col4                                                    3
# col5                                              -213.25
# col6                                                38.94
# col7                                                 35.0
# col8                                              Nunavut
# col9                               Storage & Organization
# col10                                                 0.8
# Name: 0, dtype: object

# %%
abhi.loc[0]
# Out:
# col1                                                    1
# col2     Eldon Base for stackable storage shelf, platinum
# col3                                   Muhammed MacIntyre
# col4                                                    3
# col5                                              -213.25
# col6                                                38.94
# col7                                                 35.0
# col8                                              Nunavut
# col9                               Storage & Organization
# col10                                                 0.8
# Name: 0, dtype: object

# %%
abhi.loc[2:3]
# Out:
#    col1                                              col2           col3  \
# 2     3  Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl   Barry French
# 3     4                                              R380  Clay Rozendal
#
#    col4     col5    col6  col7     col8                            col9  col10
# 2   293    46.71    8.69  2.99  Nunavut  Binders and Binder Accessories   0.39
# 3   483  1198.97  195.99  3.99  Nunavut    Telephones and Communication   0.58

# %%
abhi.loc[2:5]
# Out:
#    col1                                               col2            col3  \
# 2     3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl    Barry French
# 3     4                                               R380   Clay Rozendal
# 4     5                           Holmes HEPA Air Purifier  Carlos Soltero
# 5     6  G.E. Longer-Life Indoor Recessed Floodlight Bulbs  Carlos Soltero
#
#    col4     col5    col6  col7     col8                            col9  col10
# 2   293    46.71    8.69  2.99  Nunavut  Binders and Binder Accessories   0.39
# 3   483  1198.97  195.99  3.99  Nunavut    Telephones and Communication   0.58
# 4   515    30.94   21.78  5.94  Nunavut                      Appliances   0.50
# 5   515     4.43    6.64  4.95  Nunavut              Office Furnishings   0.37

# %%
abhi.iloc[2:5]
# Out:
#    col1                                              col2            col3  \
# 2     3  Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl    Barry French
# 3     4                                              R380   Clay Rozendal
# 4     5                          Holmes HEPA Air Purifier  Carlos Soltero
#
#    col4     col5    col6  col7     col8                            col9  col10
# 2   293    46.71    8.69  2.99  Nunavut  Binders and Binder Accessories   0.39
# 3   483  1198.97  195.99  3.99  Nunavut    Telephones and Communication   0.58
# 4   515    30.94   21.78  5.94  Nunavut                      Appliances   0.50

# %%
abhi.iloc[4,8]
# Out:
# 'Appliances'

# %%
abhi.loc[4,8]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/conda/lib/python3.10/site-packages/pandas/core/indexes/base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File /opt/conda/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File /opt/conda/lib/python3.10/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 8
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
abhi.loc[: , ['col1','col2','col3']]
# Out:
#      col1                                               col2  \
# 0       1   Eldon Base for stackable storage shelf, platinum
# 1       2  1.7 Cubic Foot Compact "Cube" Office Refrigera...
# 2       3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl
# 3       4                                               R380
# 4       5                           Holmes HEPA Air Purifier
# ..    ...                                                ...
# 995   996                                         Xerox 1905
# 996   997              Dana Halogen Swing-Arm Architect Lamp
# 997   998                               Maxell DVD-RAM Discs
# 998   999  DAX Contemporary Wood Frame with Silver Metal ...
# 999  1000  Computer Printout Paper with Letter-Trim Perfo...
#
#                    col3
# 0    Muhammed MacIntyre
# 1          Barry French
# 2          Barry French
# 3         Clay Rozendal
# 4        Carlos Soltero
# ..                  ...
# 995       Dennis Bolton
# 996   Anthony O'Donnell
# ...

# %%
abhi.iloc[: , ['col1','col2','col3']]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In [117], line 1
# ----> 1 abhi.iloc[: , ['col1','col2','col3']]
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/indexing.py:1067, in _LocationIndexer.__getitem__(self, key)
#    1065     if self._is_scalar_access(key):
#    1066         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1067     return self._getitem_tuple(key)
#    1068 else:
#    1069     # we by definition only have the 0th axis
#    1070     axis = self.axis or 0
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/indexing.py:1563, in _iLocIndexer._getitem_tuple(self, tup)
#    1561 def _getitem_tuple(self, tup: tuple):
# -> 1563     tup = self._validate_tuple_indexer(tup)
#    1564     with suppress(IndexingError):
#    1565         return self._getitem_lowerdim(tup)
#
# ...

# %%
abhi.loc[5:10 , ['col1','col2','col3']]
# Out:
#     col1                                               col2             col3
# 5      6  G.E. Longer-Life Indoor Recessed Floodlight Bulbs   Carlos Soltero
# 6      7  Angle-D Binders with Locking Rings, Label Holders     Carl Jackson
# 7      8            SAFCO Mobile Desk Side File, Wire Frame     Carl Jackson
# 8      9              SAFCO Commercial Wire Shelving, Black   Monica Federle
# 9     10                                          Xerox 198  Dorothy Badders
# 10    11                                         Xerox 1980  Neola Schneider

# %%
abhi.iloc[: , [0,1,2]]
# Out:
#      col1                                               col2  \
# 0       1   Eldon Base for stackable storage shelf, platinum
# 1       2  1.7 Cubic Foot Compact "Cube" Office Refrigera...
# 2       3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl
# 3       4                                               R380
# 4       5                           Holmes HEPA Air Purifier
# ..    ...                                                ...
# 995   996                                         Xerox 1905
# 996   997              Dana Halogen Swing-Arm Architect Lamp
# 997   998                               Maxell DVD-RAM Discs
# 998   999  DAX Contemporary Wood Frame with Silver Metal ...
# 999  1000  Computer Printout Paper with Letter-Trim Perfo...
#
#                    col3
# 0    Muhammed MacIntyre
# 1          Barry French
# 2          Barry French
# 3         Clay Rozendal
# 4        Carlos Soltero
# ..                  ...
# 995       Dennis Bolton
# 996   Anthony O'Donnell
# ...

# %%
abhi.iloc[: , :]
# Out:
#      col1                                               col2  \
# 0       1   Eldon Base for stackable storage shelf, platinum
# 1       2  1.7 Cubic Foot Compact "Cube" Office Refrigera...
# 2       3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl
# 3       4                                               R380
# 4       5                           Holmes HEPA Air Purifier
# ..    ...                                                ...
# 995   996                                         Xerox 1905
# 996   997              Dana Halogen Swing-Arm Architect Lamp
# 997   998                               Maxell DVD-RAM Discs
# 998   999  DAX Contemporary Wood Frame with Silver Metal ...
# 999  1000  Computer Printout Paper with Letter-Trim Perfo...
#
#                    col3   col4     col5    col6   col7              col8  \
# 0    Muhammed MacIntyre      3  -213.25   38.94  35.00           Nunavut
# 1          Barry French    293   457.81  208.16  68.02           Nunavut
# ...

# %%
abhi.iloc[[3,4], [1,2]]
# Out:
#                        col2            col3
# 3                      R380   Clay Rozendal
# 4  Holmes HEPA Air Purifier  Carlos Soltero

# %%
abhi.iloc[[3,7], [1,2]]
# Out:
#                                       col2           col3
# 3                                     R380  Clay Rozendal
# 7  SAFCO Mobile Desk Side File, Wire Frame   Carl Jackson

# %%
abhi.loc[[3,4], ['col1','col2']]
# Out:
#    col1                      col2
# 3     4                      R380
# 4     5  Holmes HEPA Air Purifier

# %%
abhi.loc[[3,7], ['col1','col2']]
# Out:
#    col1                                     col2
# 3     4                                     R380
# 7     8  SAFCO Mobile Desk Side File, Wire Frame

# %%
abhi.loc[3:8, ['col1','col2']]
# Out:
#    col1                                               col2
# 3     4                                               R380
# 4     5                           Holmes HEPA Air Purifier
# 5     6  G.E. Longer-Life Indoor Recessed Floodlight Bulbs
# 6     7  Angle-D Binders with Locking Rings, Label Holders
# 7     8            SAFCO Mobile Desk Side File, Wire Frame
# 8     9              SAFCO Commercial Wire Shelving, Black

# %%
abhi.head()
# Out:
#    col1                                               col2  \
# 0     1   Eldon Base for stackable storage shelf, platinum
# 1     2  1.7 Cubic Foot Compact "Cube" Office Refrigera...
# 2     3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl
# 3     4                                               R380
# 4     5                           Holmes HEPA Air Purifier
#
#                  col3  col4     col5    col6   col7     col8  \
# 0  Muhammed MacIntyre     3  -213.25   38.94  35.00  Nunavut
# 1        Barry French   293   457.81  208.16  68.02  Nunavut
# 2        Barry French   293    46.71    8.69   2.99  Nunavut
# 3       Clay Rozendal   483  1198.97  195.99   3.99  Nunavut
# 4      Carlos Soltero   515    30.94   21.78   5.94  Nunavut
#
#                              col9  col10
# 0          Storage & Organization   0.80
# 1                      Appliances   0.58
# 2  Binders and Binder Accessories   0.39
# 3    Telephones and Communication   0.58
# ...

# %%
abhi[abhi['col4'] > 850]
# Out:
#      col1                                               col2  \
# 12     13                           Holmes HEPA Air Purifier
# 13     14  DS/HD IBM Formatted Diskettes, 200/Pack - Staples
# 14     15     Wilson Jones 1" Hanging DublLock® Ring Binders
# 15     16      Ultra Commercial Grade Dual Valve Door Closer
# 16     17  #10-4 1/8" x 9 1/2" Premium Diagonal Seam Enve...
# ..    ...                                                ...
# 995   996                                         Xerox 1905
# 996   997              Dana Halogen Swing-Arm Architect Lamp
# 997   998                               Maxell DVD-RAM Discs
# 998   999  DAX Contemporary Wood Frame with Silver Metal ...
# 999  1000  Computer Printout Paper with Letter-Trim Perfo...
#
#                   col3   col4    col5   col6   col7              col8  \
# 12         Carlos Daly    868  134.72  21.78   5.94           Nunavut
# 13         Carlos Daly    868  114.46  47.98   3.61           Nunavut
# ...

# %%
demo = abhi.iloc[0:5, [0,1,3,4]]

# %%
demo
# Out:
#    col1                                               col2  col4     col5
# 0     1   Eldon Base for stackable storage shelf, platinum     3  -213.25
# 1     2  1.7 Cubic Foot Compact "Cube" Office Refrigera...   293   457.81
# 2     3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl   293    46.71
# 3     4                                               R380   483  1198.97
# 4     5                           Holmes HEPA Air Purifier   515    30.94

# %%
demo.set_index('col4')
# Out:
#       col1                                               col2     col5
# col4
# 3        1   Eldon Base for stackable storage shelf, platinum  -213.25
# 293      2  1.7 Cubic Foot Compact "Cube" Office Refrigera...   457.81
# 293      3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl    46.71
# 483      4                                               R380  1198.97
# 515      5                           Holmes HEPA Air Purifier    30.94

# %%
demo.dropna()
# Out:
#    col1                                               col2  col4     col5
# 0     1   Eldon Base for stackable storage shelf, platinum     3  -213.25
# 1     2  1.7 Cubic Foot Compact "Cube" Office Refrigera...   293   457.81
# 2     3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl   293    46.71
# 3     4                                               R380   483  1198.97
# 4     5                           Holmes HEPA Air Purifier   515    30.94

# %%
demo.dropna(axis=1)
# Out:
#    col1                                               col2  col4     col5
# 0     1   Eldon Base for stackable storage shelf, platinum     3  -213.25
# 1     2  1.7 Cubic Foot Compact "Cube" Office Refrigera...   293   457.81
# 2     3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl   293    46.71
# 3     4                                               R380   483  1198.97
# 4     5                           Holmes HEPA Air Purifier   515    30.94

# %%
demo.drop_duplicates('col4')
# Out:
#    col1                                               col2  col4     col5
# 0     1   Eldon Base for stackable storage shelf, platinum     3  -213.25
# 1     2  1.7 Cubic Foot Compact "Cube" Office Refrigera...   293   457.81
# 3     4                                               R380   483  1198.97
# 4     5                           Holmes HEPA Air Purifier   515    30.94

# %%
# dropna will drop column or rows only when a null value(atleast one) is detected.
# drop will remove entire row or column.

# %%
demo.set_index('col2')
# Out:
#                                                     col1  col4     col5
# col2
# Eldon Base for stackable storage shelf, platinum       1     3  -213.25
# 1.7 Cubic Foot Compact "Cube" Office Refrigerators     2   293   457.81
# Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl       3   293    46.71
# R380                                                   4   483  1198.97
# Holmes HEPA Air Purifier                               5   515    30.94

# %%
demo["new"]= None

# %%
demo
# Out:
#    col1                                               col2  col4     col5  \
# 0     1   Eldon Base for stackable storage shelf, platinum     3  -213.25
# 1     2  1.7 Cubic Foot Compact "Cube" Office Refrigera...   293   457.81
# 2     3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl   293    46.71
# 3     4                                               R380   483  1198.97
# 4     5                           Holmes HEPA Air Purifier   515    30.94
#
#     new
# 0  None
# 1  None
# 2  None
# 3  None
# 4  None

# %%
demo.dropna(axis=0, thresh=1)
# Out:
#    col1                                               col2  col4     col5  \
# 0     1   Eldon Base for stackable storage shelf, platinum     3  -213.25
# 1     2  1.7 Cubic Foot Compact "Cube" Office Refrigera...   293   457.81
# 2     3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl   293    46.71
# 3     4                                               R380   483  1198.97
# 4     5                           Holmes HEPA Air Purifier   515    30.94
#
#     new
# 0  None
# 1  None
# 2  None
# 3  None
# 4  None

# %%
demo.dropna(axis=0, thresh=3)
# Out:
#    col1                                               col2  col4     col5  \
# 0     1   Eldon Base for stackable storage shelf, platinum     3  -213.25
# 1     2  1.7 Cubic Foot Compact "Cube" Office Refrigera...   293   457.81
# 2     3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl   293    46.71
# 3     4                                               R380   483  1198.97
# 4     5                           Holmes HEPA Air Purifier   515    30.94
#
#     new
# 0  None
# 1  None
# 2  None
# 3  None
# 4  None

# %%
demo.dropna(axis=0, thresh=5)
# Out:
# Empty DataFrame
# Columns: [col1, col2, col4, col5, new]
# Index: []

# %%
demo
# Out:
#    col1                                               col2  col4     col5  \
# 0     1   Eldon Base for stackable storage shelf, platinum     3  -213.25
# 1     2  1.7 Cubic Foot Compact "Cube" Office Refrigera...   293   457.81
# 2     3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl   293    46.71
# 3     4                                               R380   483  1198.97
# 4     5                           Holmes HEPA Air Purifier   515    30.94
#
#     new
# 0  None
# 1  None
# 2  None
# 3  None
# 4  None

# %%
demo.dropna(axis=1, thresh=1)
# Out:
#    col1                                               col2  col4     col5
# 0     1   Eldon Base for stackable storage shelf, platinum     3  -213.25
# 1     2  1.7 Cubic Foot Compact "Cube" Office Refrigera...   293   457.81
# 2     3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl   293    46.71
# 3     4                                               R380   483  1198.97
# 4     5                           Holmes HEPA Air Purifier   515    30.94

# %%
# thresh is minimum no of non null values.

# %%
demo
# Out:
#    col1                                               col2  col4     col5  \
# 0     1   Eldon Base for stackable storage shelf, platinum     3  -213.25
# 1     2  1.7 Cubic Foot Compact "Cube" Office Refrigera...   293   457.81
# 2     3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl   293    46.71
# 3     4                                               R380   483  1198.97
# 4     5                           Holmes HEPA Air Purifier   515    30.94
#
#     new
# 0  None
# 1  None
# 2  None
# 3  None
# 4  None

# %%
avg = demo['col5'].mean()

# %%
avg
# Out:
# 304.236

# %%
demo.describe()
# Out:
#            col1        col4         col5
# count  5.000000    5.000000     5.000000
# mean   3.000000  317.400000   304.236000
# std    1.581139  204.026469   555.188258
# min    1.000000    3.000000  -213.250000
# 25%    2.000000  293.000000    30.940000
# 50%    3.000000  293.000000    46.710000
# 75%    4.000000  483.000000   457.810000
# max    5.000000  515.000000  1198.970000

# %%
demo.fillna(avg)
# Out:
#    col1                                               col2  col4     col5  \
# 0     1   Eldon Base for stackable storage shelf, platinum     3  -213.25
# 1     2  1.7 Cubic Foot Compact "Cube" Office Refrigera...   293   457.81
# 2     3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl   293    46.71
# 3     4                                               R380   483  1198.97
# 4     5                           Holmes HEPA Air Purifier   515    30.94
#
#        new
# 0  304.236
# 1  304.236
# 2  304.236
# 3  304.236
# 4  304.236

# %%
demo.groupby('col2').count()
# Out:
#                                                     col1  col4  col5  new
# col2
# 1.7 Cubic Foot Compact "Cube" Office Refrigerators     1     1     1    0
# Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl       1     1     1    0
# Eldon Base for stackable storage shelf, platinum       1     1     1    0
# Holmes HEPA Air Purifier                               1     1     1    0
# R380                                                   1     1     1    0

# %%
abhi
# Out:
#      col1                                               col2  \
# 0       1   Eldon Base for stackable storage shelf, platinum
# 1       2  1.7 Cubic Foot Compact "Cube" Office Refrigera...
# 2       3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl
# 3       4                                               R380
# 4       5                           Holmes HEPA Air Purifier
# ..    ...                                                ...
# 995   996                                         Xerox 1905
# 996   997              Dana Halogen Swing-Arm Architect Lamp
# 997   998                               Maxell DVD-RAM Discs
# 998   999  DAX Contemporary Wood Frame with Silver Metal ...
# 999  1000  Computer Printout Paper with Letter-Trim Perfo...
#
#                    col3   col4     col5    col6   col7              col8  \
# 0    Muhammed MacIntyre      3  -213.25   38.94  35.00           Nunavut
# 1          Barry French    293   457.81  208.16  68.02           Nunavut
# ...

# %%
abhi.groupby('col8').count()
# Out:
#                        col1  col2  col3  col4  col5  col6  col7  col9  col10
# col8
# British Columbia        265   265   265   265   265   265   265   265    264
# Manitoba                 51    51    51    51    51    51    51    51     51
# Northwest Territories   394   394   394   394   394   394   394   394    390
# Nunavut                  79    79    79    79    79    79    79    79     76
# Prince Edward Island    211   211   211   211   211   211   211   211    209

# %%
abhi.groupby('col8').mean()
# Out:
# /tmp/ipykernel_84/1462596336.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   abhi.groupby('col8').mean()
#                         col1          col4        col5        col6       col7  \
# col8
# British Columbia       868.0  27990.415094   94.279774   64.213094  11.902906
# Manitoba               710.0  54121.450980  123.228039   87.602353  18.112941
# Northwest Territories  276.5  31088.296954  255.464670  100.500761  13.753629
# Nunavut                 40.0   3757.379747   35.963418   76.219620  12.769494
# Prince Edward Island   579.0  30529.118483  148.633697   92.836209  14.077630
#
#                           col10
# col8
# British Columbia       0.521402
# Manitoba               0.557647
# Northwest Territories  0.518846
# Nunavut                0.510395
# ...

# %%
data1 = abhi.iloc[0:5, [0,2,3,4]]

# %%
data1
# Out:
#    0                   2    3        4
# 0  1  Muhammed MacIntyre    3  -213.25
# 1  2        Barry French  293   457.81
# 2  3        Barry French  293    46.71
# 3  4       Clay Rozendal  483  1198.97
# 4  5      Carlos Soltero  515    30.94

# %%
data2 = abhi.iloc[0:5, [5,6,7,8]]

# %%
data2
# Out:
#         5      6        7                               8
# 0   38.94  35.00  Nunavut          Storage & Organization
# 1  208.16  68.02  Nunavut                      Appliances
# 2    8.69   2.99  Nunavut  Binders and Binder Accessories
# 3  195.99   3.99  Nunavut    Telephones and Communication
# 4   21.78   5.94  Nunavut                      Appliances

# %%
pd.concat([data1,data2], axis=0)
# Out:
#    col1                col3   col4     col5    col6   col7     col8  \
# 0   1.0  Muhammed MacIntyre    3.0  -213.25     NaN    NaN      NaN
# 1   2.0        Barry French  293.0   457.81     NaN    NaN      NaN
# 2   3.0        Barry French  293.0    46.71     NaN    NaN      NaN
# 3   4.0       Clay Rozendal  483.0  1198.97     NaN    NaN      NaN
# 4   5.0      Carlos Soltero  515.0    30.94     NaN    NaN      NaN
# 0   NaN                 NaN    NaN      NaN   38.94  35.00  Nunavut
# 1   NaN                 NaN    NaN      NaN  208.16  68.02  Nunavut
# 2   NaN                 NaN    NaN      NaN    8.69   2.99  Nunavut
# 3   NaN                 NaN    NaN      NaN  195.99   3.99  Nunavut
# 4   NaN                 NaN    NaN      NaN   21.78   5.94  Nunavut
#
#                              col9
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN
# ...

# %%
pd.concat([data1,data2], axis=1)
# Out:
#    col1                col3  col4     col5    col6   col7     col8  \
# 0     1  Muhammed MacIntyre     3  -213.25   38.94  35.00  Nunavut
# 1     2        Barry French   293   457.81  208.16  68.02  Nunavut
# 2     3        Barry French   293    46.71    8.69   2.99  Nunavut
# 3     4       Clay Rozendal   483  1198.97  195.99   3.99  Nunavut
# 4     5      Carlos Soltero   515    30.94   21.78   5.94  Nunavut
#
#                              col9
# 0          Storage & Organization
# 1                      Appliances
# 2  Binders and Binder Accessories
# 3    Telephones and Communication
# 4                      Appliances

# %%
data1
# Out:
#    0                   2    3        4
# 0  1  Muhammed MacIntyre    3  -213.25
# 1  2        Barry French  293   457.81
# 2  3        Barry French  293    46.71
# 3  4       Clay Rozendal  483  1198.97
# 4  5      Carlos Soltero  515    30.94

# %%
data2
# Out:
#         5      6        7                               8
# 0   38.94  35.00  Nunavut          Storage & Organization
# 1  208.16  68.02  Nunavut                      Appliances
# 2    8.69   2.99  Nunavut  Binders and Binder Accessories
# 3  195.99   3.99  Nunavut    Telephones and Communication
# 4   21.78   5.94  Nunavut                      Appliances

# %%
abhi
# Out:
#      col1                                               col2  \
# 0       1   Eldon Base for stackable storage shelf, platinum
# 1       2  1.7 Cubic Foot Compact "Cube" Office Refrigera...
# 2       3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl
# 3       4                                               R380
# 4       5                           Holmes HEPA Air Purifier
# ..    ...                                                ...
# 995   996                                         Xerox 1905
# 996   997              Dana Halogen Swing-Arm Architect Lamp
# 997   998                               Maxell DVD-RAM Discs
# 998   999  DAX Contemporary Wood Frame with Silver Metal ...
# 999  1000  Computer Printout Paper with Letter-Trim Perfo...
#
#                    col3   col4     col5    col6   col7              col8  \
# 0    Muhammed MacIntyre      3  -213.25   38.94  35.00           Nunavut
# 1          Barry French    293   457.81  208.16  68.02           Nunavut
# ...

# %%
abhi['new']= abhi['col4'].apply(lambda x: x/3)

# %%
abhi.head()
# Out:
#    col1                                               col2  \
# 0     1   Eldon Base for stackable storage shelf, platinum
# 1     2  1.7 Cubic Foot Compact "Cube" Office Refrigera...
# 2     3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl
# 3     4                                               R380
# 4     5                           Holmes HEPA Air Purifier
#
#                  col3  col4     col5    col6   col7     col8  \
# 0  Muhammed MacIntyre     3  -213.25   38.94  35.00  Nunavut
# 1        Barry French   293   457.81  208.16  68.02  Nunavut
# 2        Barry French   293    46.71    8.69   2.99  Nunavut
# 3       Clay Rozendal   483  1198.97  195.99   3.99  Nunavut
# 4      Carlos Soltero   515    30.94   21.78   5.94  Nunavut
#
#                              col9  col10         new
# 0          Storage & Organization   0.80    1.000000
# 1                      Appliances   0.58   97.666667
# 2  Binders and Binder Accessories   0.39   97.666667
# ...

# %%
def fun1(x):
    return x/3

# %%
abhi['new1']= abhi['col4'].apply(fun1)

# %%
abhi
# Out:
#      col1                                               col2  \
# 0       1   Eldon Base for stackable storage shelf, platinum
# 1       2  1.7 Cubic Foot Compact "Cube" Office Refrigera...
# 2       3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl
# 3       4                                               R380
# 4       5                           Holmes HEPA Air Purifier
# ..    ...                                                ...
# 995   996                                         Xerox 1905
# 996   997              Dana Halogen Swing-Arm Architect Lamp
# 997   998                               Maxell DVD-RAM Discs
# 998   999  DAX Contemporary Wood Frame with Silver Metal ...
# 999  1000  Computer Printout Paper with Letter-Trim Perfo...
#
#                    col3   col4     col5    col6   col7              col8  \
# 0    Muhammed MacIntyre      3  -213.25   38.94  35.00           Nunavut
# 1          Barry French    293   457.81  208.16  68.02           Nunavut
# ...

# %%
abhi.drop('new', axis =1, inplace = True)

# %%
abhi.drop('new1', axis =1, inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [26], line 1
# ----> 1 abhi.drop('new1', axis =1, inplace = True)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/frame.py:5388, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5240 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5241 def drop(  # type: ignore[override]
#    5242     self,
# ...

# %%
abhi
# Out:
#      col1                                               col2  \
# 0       1   Eldon Base for stackable storage shelf, platinum
# 1       2  1.7 Cubic Foot Compact "Cube" Office Refrigera...
# 2       3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl
# 3       4                                               R380
# 4       5                           Holmes HEPA Air Purifier
# ..    ...                                                ...
# 995   996                                         Xerox 1905
# 996   997              Dana Halogen Swing-Arm Architect Lamp
# 997   998                               Maxell DVD-RAM Discs
# 998   999  DAX Contemporary Wood Frame with Silver Metal ...
# 999  1000  Computer Printout Paper with Letter-Trim Perfo...
#
#                    col3   col4     col5    col6   col7              col8  \
# 0    Muhammed MacIntyre      3  -213.25   38.94  35.00           Nunavut
# 1          Barry French    293   457.81  208.16  68.02           Nunavut
# ...

# %%
def test(x):
    if x > 15:
        return x/100
    else:
        return x

# %%
abhi['filter'] = abhi['col7'].apply(test)

# %%
abhi
# Out:
#      col1                                               col2  \
# 0       1   Eldon Base for stackable storage shelf, platinum
# 1       2  1.7 Cubic Foot Compact "Cube" Office Refrigera...
# 2       3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl
# 3       4                                               R380
# 4       5                           Holmes HEPA Air Purifier
# ..    ...                                                ...
# 995   996                                         Xerox 1905
# 996   997              Dana Halogen Swing-Arm Architect Lamp
# 997   998                               Maxell DVD-RAM Discs
# 998   999  DAX Contemporary Wood Frame with Silver Metal ...
# 999  1000  Computer Printout Paper with Letter-Trim Perfo...
#
#                    col3   col4     col5    col6   col7              col8  \
# 0    Muhammed MacIntyre      3  -213.25   38.94  35.00           Nunavut
# 1          Barry French    293   457.81  208.16  68.02           Nunavut
# ...
