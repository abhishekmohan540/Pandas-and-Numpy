# %% [markdown]
# ## Pandas Class

# %%
# With help of pandas we can read a csv file, excel file, etc.
# Pandas work with structred data only.

# %%
import pandas as pd

# %%
pd.read_csv('glass.data')
# Out:
#      index       RI     Na    Mg    Al     Si     K    Ca    Ba   Fe  Class
# 0        1  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0      1
# 1        2  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0      1
# 2        3  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0      1
# 3        4  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0      1
# 4        5  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0      1
# ..     ...      ...    ...   ...   ...    ...   ...   ...   ...  ...    ...
# 209    210  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0      7
# 210    211  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0      7
# 211    212  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0      7
# 212    213  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0      7
# 213    214  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.0      7
#
# [214 rows x 11 columns]

# %%
data = pd.read_csv('glass.data')

# %%
data
# Out:
#      index       RI     Na    Mg    Al     Si     K    Ca    Ba   Fe  Class
# 0        1  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0      1
# 1        2  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0      1
# 2        3  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0      1
# 3        4  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0      1
# 4        5  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0      1
# ..     ...      ...    ...   ...   ...    ...   ...   ...   ...  ...    ...
# 209    210  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0      7
# 210    211  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0      7
# 211    212  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0      7
# 212    213  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0      7
# 213    214  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.0      7
#
# [214 rows x 11 columns]

# %%
print(type(data))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
data.head()
# Out:
#    index       RI     Na    Mg    Al     Si     K    Ca   Ba   Fe  Class
# 0      1  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.0  0.0      1
# 1      2  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.0      1
# 2      3  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.0      1
# 3      4  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.0  0.0      1
# 4      5  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.0  0.0      1

# %%
# head() will give first 5 rows after header.

# %%
# In Pandas, first row is treated as header

# %%
data.head(10)
# Out:
#    index       RI     Na    Mg    Al     Si     K    Ca   Ba    Fe  Class
# 0      1  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.0  0.00      1
# 1      2  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.00      1
# 2      3  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.00      1
# 3      4  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.0  0.00      1
# 4      5  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.0  0.00      1
# 5      6  1.51596  12.79  3.61  1.62  72.97  0.64  8.07  0.0  0.26      1
# 6      7  1.51743  13.30  3.60  1.14  73.09  0.58  8.17  0.0  0.00      1
# 7      8  1.51756  13.15  3.61  1.05  73.24  0.57  8.24  0.0  0.00      1
# 8      9  1.51918  14.04  3.58  1.37  72.08  0.56  8.30  0.0  0.00      1
# 9     10  1.51755  13.00  3.60  1.36  72.99  0.57  8.40  0.0  0.11      1

# %%
data.tail()
# Out:
#      index       RI     Na   Mg    Al     Si     K    Ca    Ba   Fe  Class
# 209    210  1.51623  14.14  0.0  2.88  72.61  0.08  9.18  1.06  0.0      7
# 210    211  1.51685  14.92  0.0  1.99  73.06  0.00  8.40  1.59  0.0      7
# 211    212  1.52065  14.36  0.0  2.02  73.42  0.00  8.44  1.64  0.0      7
# 212    213  1.51651  14.38  0.0  1.94  73.61  0.00  8.48  1.57  0.0      7
# 213    214  1.51711  14.23  0.0  2.08  73.36  0.00  8.62  1.67  0.0      7

# %%
# Last 5 rows.

# %%
data.tail(8)
# Out:
#      index       RI     Na   Mg    Al     Si     K    Ca    Ba   Fe  Class
# 206    207  1.51645  14.94  0.0  1.87  73.11  0.00  8.67  1.38  0.0      7
# 207    208  1.51831  14.39  0.0  1.82  72.86  1.41  6.47  2.88  0.0      7
# 208    209  1.51640  14.37  0.0  2.74  72.85  0.00  9.45  0.54  0.0      7
# 209    210  1.51623  14.14  0.0  2.88  72.61  0.08  9.18  1.06  0.0      7
# 210    211  1.51685  14.92  0.0  1.99  73.06  0.00  8.40  1.59  0.0      7
# 211    212  1.52065  14.36  0.0  2.02  73.42  0.00  8.44  1.64  0.0      7
# 212    213  1.51651  14.38  0.0  1.94  73.61  0.00  8.48  1.57  0.0      7
# 213    214  1.51711  14.23  0.0  2.08  73.36  0.00  8.62  1.67  0.0      7

# %%
data.columns
# Out:
# Index(['index', 'RI', 'Na', 'Mg', 'Al', 'Si', 'K', 'Ca', 'Ba', 'Fe', 'Class'], dtype='object')

# %%
list(data.columns)
# Out:
# ['index', 'RI', 'Na', 'Mg', 'Al', 'Si', 'K', 'Ca', 'Ba', 'Fe', 'Class']

# %%
# How to select only few columns from the table

# %%
# To do so, pass the columns as a list into a dataframe.

# %%
data[['index', 'Na', 'Mg']]
# Out:
#      index     Na    Mg
# 0        1  13.64  4.49
# 1        2  13.89  3.60
# 2        3  13.53  3.55
# 3        4  13.21  3.69
# 4        5  13.27  3.62
# ..     ...    ...   ...
# 209    210  14.14  0.00
# 210    211  14.92  0.00
# 211    212  14.36  0.00
# 212    213  14.38  0.00
# 213    214  14.23  0.00
#
# [214 rows x 3 columns]

# %%
data[['index', 'Class']]
# Out:
#      index  Class
# 0        1      1
# 1        2      1
# 2        3      1
# 3        4      1
# 4        5      1
# ..     ...    ...
# 209    210      7
# 210    211      7
# 211    212      7
# 212    213      7
# 213    214      7
#
# [214 rows x 2 columns]

# %%
data['index']
# Out:
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 209    210
# 210    211
# 211    212
# 212    213
# 213    214
# Name: index, Length: 214, dtype: int64

# %%
type(data['index'])
# Out:
# pandas.core.series.Series

# %%
data[['index']]
# Out:
#      index
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
# ..     ...
# 209    210
# 210    211
# 211    212
# 212    213
# 213    214
#
# [214 rows x 1 columns]

# %%
type(data[['index']])
# Out:
# pandas.core.frame.DataFrame

# %%
#When we passsed a single column without list, the data type is series and 
#when we passed it in list, the data type is data frame.
#Also we cannot pass multiple column without list.

# %%
data['index','Class','Mg']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('index', 'Class', 'Mg')
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
data[['index','Class','Mg']]
# Out:
#      index  Class    Mg
# 0        1      1  4.49
# 1        2      1  3.60
# 2        3      1  3.55
# 3        4      1  3.69
# 4        5      1  3.62
# ..     ...    ...   ...
# 209    210      7  0.00
# 210    211      7  0.00
# 211    212      7  0.00
# 212    213      7  0.00
# 213    214      7  0.00
#
# [214 rows x 3 columns]

# %%
pd.read_excel('Sample - Superstore.xlsx')
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2018-152156 2018-11-08 2018-11-11    Second Class
# 1          2  CA-2018-152156 2018-11-08 2018-11-11    Second Class
# 2          3  CA-2018-138688 2018-06-12 2018-06-16    Second Class
# 3          4  US-2017-108966 2017-10-11 2017-10-18  Standard Class
# 4          5  US-2017-108966 2017-10-11 2017-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2016-110422 2016-01-21 2016-01-23    Second Class
# 9990    9991  CA-2019-121258 2019-02-26 2019-03-03  Standard Class
# 9991    9992  CA-2019-121258 2019-02-26 2019-03-03  Standard Class
# 9992    9993  CA-2019-121258 2019-02-26 2019-03-03  Standard Class
# ...

# %%
pd.read_excel('Sample - Superstore.xlsx', 'People')
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
#               Person   Region
# 0      Anna Andreadi     West
# 1        Chuck Magee     East
# 2     Kelly Williams  Central
# 3  Cassandra Brandow    South

# %%
pd.read_excel('Sample - Superstore.xlsx', sheet_name = 'People')
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
#               Person   Region
# 0      Anna Andreadi     West
# 1        Chuck Magee     East
# 2     Kelly Williams  Central
# 3  Cassandra Brandow    South

# %%
pd.read_excel('Sample - Superstore.xlsx', sheet_name = 'Returns')
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
#     Returned        Order ID
# 0        Yes  CA-2016-100762
# 1        Yes  CA-2016-100762
# 2        Yes  CA-2016-100762
# 3        Yes  CA-2016-100762
# 4        Yes  CA-2016-100867
# ..       ...             ...
# 795      Yes  US-2019-147886
# 796      Yes  US-2019-147998
# 797      Yes  US-2019-151127
# 798      Yes  US-2019-155999
# 799      Yes  US-2019-155999
#
# [800 rows x 2 columns]

# %%
# Orders,People and Return  are three sheets name in the Smaple-Superstore excel file

# %%
# To avoid the first row taken as header , what we can do is:

# %%
pd.read_excel('Sample - Superstore.xlsx', sheet_name = 'People', header = None)
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
#                    0        1
# 0             Person   Region
# 1      Anna Andreadi     West
# 2        Chuck Magee     East
# 3     Kelly Williams  Central
# 4  Cassandra Brandow    South

# %%
#How to rename thiese columns

# %%
pd.read_excel('Sample - Superstore.xlsx', sheet_name='People', header =None, names = ['column1','column2'])
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
#              column1  column2
# 0             Person   Region
# 1      Anna Andreadi     West
# 2        Chuck Magee     East
# 3     Kelly Williams  Central
# 4  Cassandra Brandow    South

# %%
pd.read_excel('Sample - Superstore.xlsx', sheet_name='People')
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
#               Person   Region
# 0      Anna Andreadi     West
# 1        Chuck Magee     East
# 2     Kelly Williams  Central
# 3  Cassandra Brandow    South

# %%
pd.read_excel('Sample - Superstore.xlsx', sheet_name='People', names=['Column-A', 'Column-B'])
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
#             Column-A Column-B
# 0      Anna Andreadi     West
# 1        Chuck Magee     East
# 2     Kelly Williams  Central
# 3  Cassandra Brandow    South

# %%
data1 = pd.read_excel('Sample - Superstore.xlsx', sheet_name='People', names=['Column-A', 'Column-B'])
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")

# %%
data1.to_csv('Superstore.csv', index = False)   #To save the changes that we have made in the file. We can save it in any file format ie csv, xlsx etc.

# %%
data1.to_csv('Superstore1.xlsx', index = False)

# %%
# Check both files Superstore.csv and Superstore1.xlsx in Home page

# %%
data1.head(2)
# Out:
#         Column-A Column-B
# 0  Anna Andreadi     West
# 1    Chuck Magee     East

# %%
data1.tail(2)
# Out:
#             Column-A Column-B
# 2     Kelly Williams  Central
# 3  Cassandra Brandow    South

# %%
data1.columns
# Out:
# Index(['Column-A', 'Column-B'], dtype='object')

# %%
data1[['Column-A']]
# Out:
#             Column-A
# 0      Anna Andreadi
# 1        Chuck Magee
# 2     Kelly Williams
# 3  Cassandra Brandow

# %%
# pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')

#To directly upload the data from github

# %%
# To upload the data from website, we can directly pass the linkn of the website to read function. 
# But note that only tabular data from web page will be uploaded.

# %%
pip install lxml
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 45.7 MB/s eta 0:00:0000:0100:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pd.read_html('https://www.basketball-reference.com/leagues/NBA_2015_totals.html')
# Out:
# [      Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
#  0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
#  1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
#  2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
#  3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
#  4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
#  ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
#  670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
#  671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
#  672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
#  673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
#  674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
# All the data has been stored in a list

# %%
data2 = pd.read_html('https://www.basketball-reference.com/leagues/NBA_2015_totals.html')

# %%
data2
# Out:
# [      Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
#  0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
#  1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
#  2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
#  3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
#  4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
#  ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
#  670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
#  671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
#  672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
#  673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
#  674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
type(data2)
# Out:
# list

# %%
len(data2)
# Out:
# 1

# %%
# Means only 1 table there

# %%
data2[0]
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
data2[0].to_excel('Basketball_players.xlsx')

# %%
data2[0].to_csv('Basketball_players.csv')
